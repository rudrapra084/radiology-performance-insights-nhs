# %%
import pandas as pd
from google.colab import files


# -----------------------------
# Step 1: Define file paths and read data
# -----------------------------
####AND
# -----------------------------
# Step 2: Read the Provider sheet (already done in Step 1)
# -----------------------------
# The actual table starts at row 13 (header=12) in these NHS files
# df1 = pd.read_excel(file1, sheet_name="Provider", header=12) # Removed redundant line
# df2 = pd.read_excel(file2, sheet_name="Provider", header=12) # Removed redundant line
# df3 = pd.read_excel(file3, sheet_name="Provider", header=12) # Removed redundant line


# Modality Provider Counts
url = "https://docs.google.com/spreadsheets/d/1NVr9HQbkIpyiQcEAyguJRK-xNFqRQ4oC/edit?usp=sharing&ouid=117443651029460089438&rtpof=true&sd=true"
path1 = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
df1 = pd.read_excel(path1, sheet_name="Provider", header=12)

# Modality Provider Request to Test
url = "https://docs.google.com/spreadsheets/d/1MTrOXWxLwRuFYdDyeeiYZWuxos4M-pzy/edit?usp=sharing&ouid=117443651029460089438&rtpof=true&sd=true"
path2 = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
df2 = pd.read_excel(path2, sheet_name="Provider", header=12)

# Modality Provider Test to Report
url = "https://docs.google.com/spreadsheets/d/1bFPrmO8l0P2XBH6u9ZUGoM12KjnoKp6F/edit?usp=sharing&ouid=117443651029460089438&rtpof=true&sd=true"
path3 = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
df3 = pd.read_excel(path3, sheet_name="Provider", header=12)




# -----------------------------
# Step 3: Select key columns and renamed date columns in all three dataframes
# -----------------------------
cols_to_keep = ["Region", "Org Code", "Provider name", "Modality", "Year to date"]

t1 = df1[cols_to_keep].rename(columns={"Year to date": "Total_Scans"})
t2 = df2[cols_to_keep].rename(columns={"Year to date": "RequestToTest_Days"})
t3 = df3[cols_to_keep].rename(columns={"Year to date": "TestToReport_Days"})

# -----------------------------
# Step 4: Merge all tables
# -----------------------------
merge_keys = ["Region", "Org Code", "Provider name", "Modality"]

merged = (
    t1.merge(t2[merge_keys + ["RequestToTest_Days"]], on=merge_keys, how="left")
      .merge(t3[merge_keys + ["TestToReport_Days"]], on=merge_keys, how="left")
)

# -----------------------------
# Step 5: Clean numeric values
# -----------------------------
for col in ["Total_Scans", "RequestToTest_Days", "TestToReport_Days"]:
    merged[col] = (
        merged[col].astype(str)
        .str.replace(",", "", regex=False)
        .str.replace("-", "", regex=False)
        .replace("nan", None)
    )
    merged[col] = pd.to_numeric(merged[col], errors="coerce")

# -----------------------------
# Step 6: Create derived metric (e.g.,Total_Turnaround_Days would represent the total time from when your doctor requests the X-ray to when the final report from the radiologist is ready)
# -----------------------------
merged["Total_Turnaround_Days"] = (
    merged["RequestToTest_Days"] + merged["TestToReport_Days"]
)

numeric_columns = ['Total_Scans', 'RequestToTest_Days', 'TestToReport_Days', 'Total_Turnaround_Days']

for col in numeric_columns:
    merged[col] = pd.to_numeric(merged[col], errors='coerce')  # Convert to numeric, invalid -> NaN


# -----------------------------
# Step 7: Export clean dataset
# -----------------------------
merged.to_csv("diagnostic_imaging_tidy.csv", index=False, quoting=1)
files.download("diagnostic_imaging_tidy.csv")

# %%
merged.head(50)
# Out:
#    Region Org Code                                      Provider name  \
# 0       -        -                                            ENGLAND
# 1       -        -                                            ENGLAND
# 2       -        -                                            ENGLAND
# 3       -        -                                            ENGLAND
# 4       -        -                                            ENGLAND
# 5       -        -                                            ENGLAND
# 6       -        -                                            ENGLAND
# 7       -        -                                            ENGLAND
# 8       -        -                                            ENGLAND
# 9     NaN      NaN                                                NaN
# 10    NaN      NaN                                                NaN
# 11    NaN      NaN                                                NaN
# 12    NaN      NaN                                                NaN
# 13    NaN      NaN                                                NaN
# 14    NaN      NaN                                                NaN
# 15    NaN      NaN                                                NaN
# 16    NaN      NaN                                                NaN
# 17    NaN      NaN                                                NaN
# 18    Y56      NT9                                   Alliance Medical
# 19    Y56      NT9                                   Alliance Medical
# 20    Y56      NT9                                   Alliance Medical
# 21    Y56      NT9                                   Alliance Medical
# 22    Y56      NT9                                   Alliance Medical
# 23    Y56      RF4  Barking, Havering and Redbridge University Hos...
# 24    Y56      RF4  Barking, Havering and Redbridge University Hos...
# 25    Y56      RF4  Barking, Havering and Redbridge University Hos...
# 26    Y56      RF4  Barking, Havering and Redbridge University Hos...
# 27    Y56      RF4  Barking, Havering and Redbridge University Hos...
# 28    Y56      RF4  Barking, Havering and Redbridge University Hos...
# 29    Y56      RF4  Barking, Havering and Redbridge University Hos...
# 30    Y56      R1H                             Barts Health NHS Trust
# 31    Y56      R1H                             Barts Health NHS Trust
# 32    Y56      R1H                             Barts Health NHS Trust
# 33    Y56      R1H                             Barts Health NHS Trust
# 34    Y56      R1H                             Barts Health NHS Trust
# 35    Y56      R1H                             Barts Health NHS Trust
# 36    Y56      R1H                             Barts Health NHS Trust
# 37    Y56      R1H                             Barts Health NHS Trust
# 38    Y56      RQM  Chelsea and Westminster Hospital NHS Foundatio...
# 39    Y56      RQM  Chelsea and Westminster Hospital NHS Foundatio...
# 40    Y56      RQM  Chelsea and Westminster Hospital NHS Foundatio...
# 41    Y56      RQM  Chelsea and Westminster Hospital NHS Foundatio...
# 42    Y56      RQM  Chelsea and Westminster Hospital NHS Foundatio...
# 43    Y56      RQM  Chelsea and Westminster Hospital NHS Foundatio...
# 44    Y56      RQM  Chelsea and Westminster Hospital NHS Foundatio...
# 45    Y56      RQM  Chelsea and Westminster Hospital NHS Foundatio...
# 46    Y56      NT4                        Circle Health Group Limited
# 47    Y56      NT4                        Circle Health Group Limited
# 48    Y56      NT4                        Circle Health Group Limited
# 49    Y56      NT4                        Circle Health Group Limited
#
#                                           Modality  Total_Scans  \
# 0                    Computerized Axial Tomography    8291725.0
# 1                       Diagnostic Ultrasonography   11439175.0
# 2                                      Fluoroscopy     959480.0
# 3                       Magnetic Resonance Imaging    4837820.0
# 4                              Medical Photography      67400.0
# 5                       Nuclear Medicine Procedure     321835.0
# 6                                Plain Radiography   23346900.0
# 7                     Positron Emission Tomography     299550.0
# 8   Single Photon Emission Computerized Tomography      58620.0
# 9                                              NaN          NaN
# 10                                             NaN          NaN
# 11                                             NaN          NaN
# 12                                             NaN          NaN
# 13                                             NaN          NaN
# 14                                             NaN          NaN
# 15                                             NaN          NaN
# 16                                             NaN          NaN
# 17                                             NaN          NaN
# 18                   Computerized Axial Tomography        795.0
# 19                      Diagnostic Ultrasonography       1780.0
# 20                      Magnetic Resonance Imaging      20310.0
# 21                               Plain Radiography        970.0
# 22                    Positron Emission Tomography       7025.0
# 23                   Computerized Axial Tomography      95290.0
# 24                      Diagnostic Ultrasonography     175555.0
# 25                                     Fluoroscopy       7850.0
# 26                      Magnetic Resonance Imaging      56430.0
# 27                      Nuclear Medicine Procedure       4185.0
# 28                               Plain Radiography     289635.0
# 29  Single Photon Emission Computerized Tomography       1515.0
# 30                   Computerized Axial Tomography     151335.0
# 31                      Diagnostic Ultrasonography     346355.0
# 32                                     Fluoroscopy      20010.0
# 33                      Magnetic Resonance Imaging      72805.0
# 34                      Nuclear Medicine Procedure       5205.0
# 35                               Plain Radiography     418920.0
# 36                    Positron Emission Tomography       9730.0
# 37  Single Photon Emission Computerized Tomography        415.0
# 38                   Computerized Axial Tomography      93960.0
# 39                      Diagnostic Ultrasonography     155885.0
# 40                                     Fluoroscopy       5065.0
# 41                      Magnetic Resonance Imaging      37415.0
# 42                      Nuclear Medicine Procedure       5655.0
# 43                               Plain Radiography     242135.0
# 44                    Positron Emission Tomography         35.0
# 45  Single Photon Emission Computerized Tomography       1035.0
# 46                   Computerized Axial Tomography       3260.0
# 47                      Diagnostic Ultrasonography       6995.0
# 48                                     Fluoroscopy         45.0
# 49                      Magnetic Resonance Imaging      14180.0
#
#     RequestToTest_Days  TestToReport_Days  Total_Turnaround_Days
# 0                  1.0                0.0                    1.0
# 1                 15.0                0.0                   15.0
# 2                  0.0                0.0                    0.0
# 3                 21.0                4.0                   25.0
# 4                  0.0                0.0                    0.0
# 5                 22.0                1.0                   23.0
# 6                  0.0                1.0                    1.0
# 7                  9.0                2.0                   11.0
# 8                 19.0                2.0                   21.0
# 9                  NaN                NaN                    NaN
# 10                 NaN                NaN                    NaN
# 11                 NaN                NaN                    NaN
# 12                 NaN                NaN                    NaN
# 13                 NaN                NaN                    NaN
# 14                 NaN                NaN                    NaN
# 15                 NaN                NaN                    NaN
# 16                 NaN                NaN                    NaN
# 17                 NaN                NaN                    NaN
# 18                 4.0                8.0                   12.0
# 19                10.0                1.0                   11.0
# 20                 8.0                4.0                   12.0
# 21                58.5                NaN                    NaN
# 22                 9.0                2.0                   11.0
# 23                 0.0                0.0                    0.0
# 24                13.0                0.0                   13.0
# 25                 1.0                1.0                    2.0
# 26                20.0                3.0                   23.0
# 27                23.0                1.0                   24.0
# 28                 0.0                0.0                    0.0
# 29                 8.0                0.0                    8.0
# 30                 0.0                0.0                    0.0
# 31                21.0                0.0                   21.0
# 32                 0.0                0.0                    0.0
# 33                32.0                6.0                   38.0
# 34                16.0                1.0                   17.0
# 35                 0.0                6.0                    6.0
# 36                17.0                3.0                   20.0
# 37                26.0                1.0                   27.0
# 38                 0.0                0.0                    0.0
# 39                 0.0                0.0                    0.0
# 40                 0.0                0.0                    0.0
# 41                 0.0                6.0                    6.0
# 42                 0.0                2.0                    2.0
# 43                 0.0                1.0                    1.0
# 44                 0.0                9.0                    9.0
# 45                 0.0                4.0                    4.0
# 46                 9.0                4.0                   13.0
# 47                12.0                0.0                   12.0
# 48                14.0                1.5                   15.5
# 49                 8.0                2.0                   10.0
